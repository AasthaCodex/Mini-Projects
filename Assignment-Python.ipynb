# %% [markdown]
# ---
# ---
#
# <center><h1>Assignment- Python</h1></center>
#
#
# ---
#
# ---

# %% [markdown]
# #### Q1. Write a Python program to create a function to check, if a given number is odd or even. The function should take any number as an argument, and if it is odd then print ‘odd’, if it is even then print ‘even’.

# %%
def odd_or_even(num):
    if((num%2) == 0):
        return 'even'
    else:
        return 'odd'

# Example usage
odd_or_even(10)
odd_or_even(11)
# Out:
# 'odd'

# %% [markdown]
# #### Q2. Write a Python program to create a function to input a number and find out if the number is prime or not. If it is prime then return ‘Prime’, if it is not prime then return ‘Not Prime’.

# %%
def is_prime(n):
    if n > 1:
        for i in range(2, int(n/2)+1):
            if (n % i) == 0:
                return "Not Prime"
        else:
            return "Prime"
    else:
        return "Not Prime"

# Example usage
number = int(input("Enter a number: "))
output = is_prime(number)
print(output)
# Out:
# Enter a number: 57
# Not Prime

# %% [markdown]
# #### Q3. Write a program to convert the given dictionary into a DataFrame & print the “Team”, “Year” & “Points” columns for the last 4 rows, using the iloc function.

# %%
import pandas as pd

ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3, 4, 1, 1, 2, 4, 1, 2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]
}

data_frame = pd.DataFrame(ipl_data)

data_frame.iloc[-4:, [0, 2, 3]]
# Out:
#       Team  Year  Points
# 8   Riders  2016     694
# 9   Royals  2014     701
# 10  Royals  2015     804
# 11  Riders  2017     690

# %% [markdown]
# #### Q4. Write a Python program to create a function that counts the number of vowels and consonants in a given string.

# %%
def count_vowels_consonants(string):
    
    count_of_vowels = 0;
    count_of_consonants = 0;
    
    string = string.lower();
    
    string_length = len(string);
    
    for i in range(0, string_length):
        if(string[i] == 'a' or string[i] == 'e' or string[i] == 'i' or string[i] == 'o' or string[i] == 'u'):
            count_of_vowels = count_of_vowels + 1
        elif(string[i] >= "a" and string[i] <= "z"):
            count_of_consonants = count_of_consonants + 1
    
    return count_of_vowels, count_of_consonants

# Example usage
vowels, consonants = count_vowels_consonants("Hello World!123")
print("Vowels:", vowels)
print("Consonants:", consonants)
# Out:
# Vowels: 3
# Consonants: 7

# %% [markdown]
# #### Q5. Write a Python program to create a function which should count the number of occurrences of each character in a given string and store the result in a dictionary.

# %%
def count_chars(string):
    
    count = {};
    
    for i in string:
        if i in count:
            count[i] = count[i] + 1
        else:
            count[i] = 1
    return count

# Example usage
print(count_chars("hello world-123"))
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '-': 1, '1': 1, '2': 1, '3': 1}

# %% [markdown]
# #### Q6. Write Python program to read the "big_mart.csv" file.

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

data_frame.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %% [markdown]
# #### Q7. Write a Python program to print the average weight of items from the "big_mart" dataset.

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

items_weight = data_frame["Item_Weight"]

average_weight = items_weight.mean()

print('The average weight of items in big_mart dataset is =', average_weight)
# Out:
# The average weight of items in big_mart dataset is = 12.857645184136183

# %% [markdown]
# #### Q8. Write a Python program to print the unique values in the "Item_type" column from the "big_mart" dataset.

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

items_type = data_frame["Item_Type"]

unique_values = items_type.unique()

print("The unique values in Item_type columns are as follow :-")

j = 0;

for i in unique_values:
    j = j + 1
    print(j, i)
# Out:
# The unique values in Item_type columns are as follow :-
# 1 Dairy
# 2 Soft Drinks
# 3 Meat
# 4 Fruits and Vegetables
# 5 Household
# 6 Baking Goods
# 7 Snack Foods
# 8 Frozen Foods
# 9 Breakfast
# 10 Health and Hygiene
# 11 Hard Drinks
# 12 Canned
# 13 Breads
# 14 Starchy Foods
# 15 Others
# 16 Seafood

# %% [markdown]
# #### Q9. Write a Python program to print the number of rows from the "big_mart" dataset, where the "Outlet_Size" is null.

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

no_of_rows = data_frame["Outlet_Size"].isna().sum()

print("The number of rows where the Outlet_Size is null are =", no_of_rows)
# Out:
# The number of rows where the Outlet_Size is null are = 2410

# %% [markdown]
# #### Q10. Write a Python program to print the number of rows from the "big_mart" dataset, where "Item_Visibility" is equal to 0.

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")
rows = data_frame.loc[data_frame["Item_Visibility"] == 0]

print("The total number of rows where Item_Visibility is equal to 0 are", len(rows))

rows
# Out:
# The total number of rows where Item_Visibility is equal to 0 are 526
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular              0.0
# 4              NCD19        8.930          Low Fat              0.0
# 5              FDP36       10.395          Regular              0.0
# 10             FDY07       11.800          Low Fat              0.0
# 32             FDP33       18.700          Low Fat              0.0
# ...              ...          ...              ...              ...
# 8480           FDQ58          NaN          Low Fat              0.0
# 8484           DRJ49        6.865          Low Fat              0.0
# 8486           FDR20       20.000          Regular              0.0
# 8494           NCI54       15.200          Low Fat              0.0
# 8500           NCQ42       20.350          Low Fat              0.0
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 10    Fruits and Vegetables   45.5402            OUT049
# 32              Snack Foods  256.6672            OUT018
# ...                     ...       ...               ...
# 8480            Snack Foods  154.5340            OUT019
# 8484            Soft Drinks  129.9652            OUT013
# 8486  Fruits and Vegetables   46.4744            OUT010
# 8494              Household  110.4912            OUT017
# 8500              Household  125.1678            OUT017
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# 5                          2009      Medium               Tier 3
# 10                         1999      Medium               Tier 1
# 32                         2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8480                       1985       Small               Tier 1
# 8484                       1987        High               Tier 3
# 8486                       1998         NaN               Tier 3
# 8494                       2007         NaN               Tier 2
# 8500                       2007         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# 5     Supermarket Type2           556.6088
# 10    Supermarket Type1          1516.0266
# 32    Supermarket Type2          3068.0064
# ...                 ...                ...
# 8480      Grocery Store           459.4020
# 8484  Supermarket Type1          2324.9736
# 8486      Grocery Store            45.2744
# 8494  Supermarket Type1          1637.8680
# 8500  Supermarket Type1          1907.5170
#
# [526 rows x 12 columns]

# %% [markdown]
# #### Q11. Write a Python program to print the average sales of each "Item_Type" in the "big_mart" dataset.

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

data_frame.groupby("Item_Type")["Item_Outlet_Sales"].mean()
# Out:
# Item_Type
# Baking Goods             1952.971207
# Breads                   2204.132226
# Breakfast                2111.808651
# Canned                   2225.194904
# Dairy                    2232.542597
# Frozen Foods             2132.867744
# Fruits and Vegetables    2289.009592
# Hard Drinks              2139.221622
# Health and Hygiene       2010.000265
# Household                2258.784300
# Meat                     2158.977911
# Others                   1926.139702
# Seafood                  2326.065928
# Snack Foods              2277.321739
# Soft Drinks              2006.511735
# Starchy Foods            2374.332773
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### Q12. Write a Python program to :
#
# ##### 1. Create a new column "Outlet_Age" containing the age of each outlet in years (based on 'Outlet_Establishment_Year) from the "big_mart" dataset.
# ##### 2. Create a new column "Price_Per_Unit_Weight" containing the price per unit weight for each item from the "big_mart" dataset.

# %%
from datetime import datetime
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

current_datetime = datetime.now().year

data_frame["Outlet_Age"] = (current_datetime - data_frame['Outlet_Establishment_Year'])

data_frame["Price_Per_Unit_Weight"] = (data_frame["Item_MRP"]) / (data_frame["Item_Weight"])

data_frame.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Outlet_Age  Price_Per_Unit_Weight
# 0  Supermarket Type1          3735.1380          24              26.861204
# 1  Supermarket Type2           443.4228          14               8.153581
# 2  Supermarket Type1          2097.2700          24               8.092457
# 3      Grocery Store           732.3800          25               9.484115
# 4  Supermarket Type1           994.7052          36               6.031512

# %% [markdown]
# #### Q13. Write a Python program to create a bar chart showing the total sales for each "Outlet_Identifier" from the "big_mart" dataset. Also provide title, x-label and y-label.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

sales = data_frame.groupby("Outlet_Identifier")["Item_Outlet_Sales"].sum()
x_axis = sales.index.tolist()
y_axis = sales.values.tolist()

plt.bar(x_axis, y_axis, color=['pink'])

plt.xticks(rotation=45)

plt.title('Total Sales')
plt.xlabel('Outlet Size')
plt.ylabel('Total Size')

plt.show()

# %% [markdown]
# #### Q14. Write a Python program to replace the values in the 'Item_Fat_Content' columnfrom the "big_mart" dataset, as follows: 'Low Fat' with 'LF' and 'Regular' with 'R' .

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

data_frame['Item_Fat_Content'] = data_frame['Item_Fat_Content'].replace({'Low Fat' : 'LF', 'Regular' : 'R'})

data_frame['Item_Fat_Content']
# Out:
# 0       LF
# 1        R
# 2       LF
# 3        R
# 4       LF
#         ..
# 8518    LF
# 8519     R
# 8520    LF
# 8521     R
# 8522    LF
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %% [markdown]
# #### Q15. Write a Python program to print the number of rows form the 'big_mart' dataset where 'Item_Type' is either 'Snack Foods' or 'Household'?

# %%
import pandas as pd

data_frame = pd.read_csv("big_mart.csv")

rows = data_frame.loc[(data_frame["Item_Type"] == "Snack Foods") | (data_frame["Item_Type"] == "Household")]

print("The total number of rows where where 'Item_Type' is either 'Snack Foods' or 'Household are", len(rows))

rows
# Out:
# The total number of rows where where 'Item_Type' is either 'Snack Foods' or 'Household are 2110
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 13             FDS46       17.600          Regular         0.047257
# 20             FDN22       18.850          Regular         0.138190
# ...              ...          ...              ...              ...
# 8504           NCN18          NaN          Low Fat         0.124111
# 8505           FDB46       10.500          Regular         0.094146
# 8510           FDN58       13.800          Regular         0.056862
# 8518           FDF22        6.865          Low Fat         0.056783
# 8521           FDN46        7.210          Regular         0.145221
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 4       Household   53.8614            OUT013                       1987
# 6     Snack Foods   57.6588            OUT013                       1987
# 7     Snack Foods  107.7622            OUT027                       1985
# 13    Snack Foods  119.6782            OUT046                       1997
# 20    Snack Foods  250.8724            OUT013                       1987
# ...           ...       ...               ...                        ...
# 8504    Household  111.7544            OUT027                       1985
# 8505  Snack Foods  210.8244            OUT018                       2009
# 8510  Snack Foods  231.5984            OUT035                       2004
# 8518  Snack Foods  214.5218            OUT013                       1987
# 8521  Snack Foods  103.1332            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 4           High               Tier 3  Supermarket Type1           994.7052
# 6           High               Tier 3  Supermarket Type1           343.5528
# 7         Medium               Tier 3  Supermarket Type3          4022.7636
# 13         Small               Tier 1  Supermarket Type1          2145.2076
# 20          High               Tier 3  Supermarket Type1          3775.0860
# ...          ...                  ...                ...                ...
# 8504      Medium               Tier 3  Supermarket Type3          4138.6128
# 8505      Medium               Tier 3  Supermarket Type2          2117.2440
# 8510       Small               Tier 2  Supermarket Type1          7182.6504
# 8518        High               Tier 3  Supermarket Type1          2778.3834
# 8521      Medium               Tier 3  Supermarket Type2          1845.5976
#
# [2110 rows x 12 columns]

# %% [markdown]
# ---
# <center><h1>END</h1></center>
#
# ---
